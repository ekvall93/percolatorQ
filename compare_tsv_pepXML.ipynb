# %%
import pandas as pd
from pyteomics import pepxml

# %%
tsv = pd.read_csv("/sdd/proteomics/DATA/PXD014076/pin_pepxml_tsv/Aposymb_Proteome_DIA_RAW_A01_Q1.tsv", sep="\t")

# %%
pepXML = pepxml.DataFrame("/sdd/proteomics/DATA/PXD014076/pin_pepxml_tsv/Aposymb_Proteome_DIA_RAW_A01_Q1.pepXML")

# %%
pepXML[pepXML.start_scan == 38287].T
# Out:
#                                                                              26923
# uncalibrated_precursor_neutral_mass                                      2470.2207
# assumed_charge                                                                   3
# native_id                                                              index=38286
# spectrum                             Aposymb_Proteome_DIA_RAW_A01_Q1.38287.38287.3
# precursor_neutral_mass                                                     2470.22
# retention_time_sec                                                         2498.12
# start_scan                                                                   38287
# end_scan                                                                     38287
# index                                                                        29770
# protein                                               [AIPGENE25192, AIPGENE25193]
# ...

# %%
tsv[tsv.scannum == 38287].T
# Out:
#                                                           26923
# scannum                                                   38287
# precursor_neutral_mass                                  2470.22
# retention_time                                          41.6354
# charge                                                        3
# hit_rank                                                      1
# peptide                            KGPDGAPGPAGPAGPQGDPGVDGAMGPK
# peptide_prev_aa                                               K
# peptide_next_aa                                               G
# protein                                            AIPGENE25192
# num_matched_ions                                             18
# tot_num_ions                                                108
# calc_neutral_pep_mass                                   2470.15
# massdiff                                               0.064453
# num_tol_term                                                  2
# ...
