# %%
import pandas as pd

# %%
/home/ekvall/diann/
# Out:
# /home/ekvall/percolatorQ

# %%
# !/home/ekvall/diann/diann-linux --f /sdd/proteomics/DATA/turbec/mzML/Sample1.mzML \
--lib /home/ekvall/Desktop/tutorial_iprophet/easypqp_lib_openswath.tsv \
--out ./data/diann_out.tsv
# Out:
# DIA-NN 1.7.12 (Data Independent Acquisition by Neural Networks)
# Compiled on Feb 13 2021 17:30:41
# Current date and time: Wed Feb 24 19:43:48 2021
# Logical CPU cores: 8
#
# 1 files will be processed
# [0:00] Loading spectral library /home/ekvall/Desktop/tutorial_iprophet/easypqp_lib_openswath.tsv
# WARNING: no fragment charge information found in the library - assuming fragments with charge 1
# [0:00] Finding proteotypic peptides (assuming that the list of UniProt ids provided for each peptide is complete)
# [0:00] Spectral library loaded: 153 protein isoforms, 153 protein groups and 176 precursors in 176 elution groups.
# [0:00] Initialising library
# WARNING: not all fragments recognised; generator accuracy threshold increased to 1e-05
# WARNING: not all fragments recognised; generator accuracy threshold increased to 2e-05
# [0:00] Saving the library to /home/ekvall/Desktop/tutorial_iprophet/easypqp_lib_openswath.tsv.speclib
#
# [0:00] File #1/1
# ...

# %%
diann_out = pd.read_csv("./data/diann_out.tsv", sep="\t")

# %%
diann_out.head(3).T
# Out:
#                                                                           0  \
# File.Name                     /sdd/proteomics/DATA/turbec/mzML/Sample1.mzML
# Run                                                                 Sample1
# Protein.Group                                                        P9WIS7
# Protein.Ids                                                          P9WIS7
# Protein.Names                                                           NaN
# Genes                                                                   NaN
# PG.Quantity                                                         16906.9
# PG.Normalised                                                       16906.9
# Genes.Quantity                                                          NaN
# Genes.Normalised                                                        NaN
# Genes.MaxLFQ                                                            NaN
# ...

# %%
diann_stats_out = pd.read_csv("./data/diann_out.stats.tsv", sep="\t")

# %%
diann_stats_out.T
# Out:
#                                                                               0
# File.Name                         /sdd/proteomics/DATA/turbec/mzML/Sample1.mzML
# Precursors.Identified                                                       167
# Proteins.Identified                                                          17
# Total.Quantity                                                      6.54898e+07
# MS1.Signal                                                          3.08149e+10
# MS2.Signal                                                          6.26343e+10
# FWHM.Scans                                                               5.7405
# FWHM.RT                                                                0.327818
# Median.Mass.Acc.MS1                                                     4.88634
# Median.Mass.Acc.MS1.Corrected                                           2.12848
# Median.Mass.Acc.MS2                                                     4.22211
# ...
