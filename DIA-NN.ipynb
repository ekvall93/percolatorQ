# %%
import pandas as pd

# %% [markdown]
# Two spectral libraries

# %%
/home/ekvall/diann/
# Out:
# /home/ekvall/percolatorQ

# %%
# !/home/ekvall/diann/diann-linux --f /sdd/proteomics/DATA/PXD014076/mzML/Symb_Proteome_DIA_RAW_S01.mzML \
--lib /home/ekvall/Desktop/sample_comp/s1/library.tsv \
--out /home/ekvall/Desktop/sample_comp/s1/diann_S01.tsv
# Out:
# DIA-NN 1.7.12 (Data Independent Acquisition by Neural Networks)
# Compiled on Feb 13 2021 17:30:41
# Current date and time: Mon Mar  1 09:44:54 2021
# Logical CPU cores: 8
#
# 1 files will be processed
# [0:00] Loading spectral library /home/ekvall/Desktop/sample_comp/s1/library.tsv
# [0:00] Finding proteotypic peptides (assuming that the list of UniProt ids provided for each peptide is complete)
# [0:00] Spectral library loaded: 142 protein isoforms, 142 protein groups and 160 precursors in 160 elution groups.
# [0:00] Initialising library
# [0:00] Saving the library to /home/ekvall/Desktop/sample_comp/s1/library.tsv.speclib
#
# [0:00] File #1/1
# [0:00] Loading run /sdd/proteomics/DATA/PXD014076/mzML/Symb_Proteome_DIA_RAW_S01.mzML
# [0:27] 160 library precursors are potentially detectable
# [0:27] Processing...
# [0:30] RT window set to 2.34521
# [0:30] Peak width: 4.86928
# [0:30] Scan window radius set to 10
# [0:31] Optimised mass accuracy: 6.02703 ppm
# ...

# %%
# !/home/ekvall/diann/diann-linux --f /sdd/proteomics/DATA/PXD014076/mzML/Symb_Proteome_DIA_RAW_S02.mzML \
--lib /home/ekvall/Desktop/sample_comp/s2/library.tsv \
--out /home/ekvall/Desktop/sample_comp/s2/diann_S02.tsv
# Out:
# DIA-NN 1.7.12 (Data Independent Acquisition by Neural Networks)
# Compiled on Feb 13 2021 17:30:41
# Current date and time: Mon Mar  1 09:45:28 2021
# Logical CPU cores: 8
#
# 1 files will be processed
# [0:00] Loading spectral library /home/ekvall/Desktop/sample_comp/s2/library.tsv
# [0:00] Finding proteotypic peptides (assuming that the list of UniProt ids provided for each peptide is complete)
# [0:00] Spectral library loaded: 134 protein isoforms, 134 protein groups and 148 precursors in 148 elution groups.
# [0:00] Initialising library
# [0:00] Saving the library to /home/ekvall/Desktop/sample_comp/s2/library.tsv.speclib
#
# [0:00] File #1/1
# [0:00] Loading run /sdd/proteomics/DATA/PXD014076/mzML/Symb_Proteome_DIA_RAW_S02.mzML
# [0:26] 148 library precursors are potentially detectable
# [0:26] Processing...
# [0:28] RT window set to 2.34862
# [0:28] Peak width: 4.96454
# [0:28] Scan window radius set to 10
# [0:31] Optimised mass accuracy: 17.5049 ppm
# ...

# %%
diann_S01 = pd.read_csv("/home/ekvall/Desktop/sample_comp/s1/diann_S01.tsv", sep="\t")
diann_S02 = pd.read_csv("/home/ekvall/Desktop/sample_comp/s2/diann_S02.tsv", sep="\t")

# %%
diann_S01.shape
# Out:
# (145, 42)

# %%
diann_S02.shape
# Out:
# (140, 42)

# %%
diann_S02.head(1).T
# Out:
#                                                                           0
# File.Name                 /sdd/proteomics/DATA/PXD014076/mzML/Symb_Prote...
# Run                                               Symb_Proteome_DIA_RAW_S02
# Protein.Group                                                  AIPGENE23810
# Protein.Ids                                                    AIPGENE23810
# Protein.Names                                                           NaN
# Genes                                                                   NaN
# PG.Quantity                                                     3.35679e+06
# PG.Normalised                                                   3.35679e+06
# Genes.Quantity                                                          NaN
# Genes.Normalised                                                        NaN
# Genes.MaxLFQ                                                            NaN
# ...

# %%
diann_S01.head(1).T
# Out:
#                                                                           0
# File.Name                 /sdd/proteomics/DATA/PXD014076/mzML/Symb_Prote...
# Run                                               Symb_Proteome_DIA_RAW_S01
# Protein.Group                                                  AIPGENE23810
# Protein.Ids                                                    AIPGENE23810
# Protein.Names                                                           NaN
# Genes                                                                   NaN
# PG.Quantity                                                     2.72134e+06
# PG.Normalised                                                   2.72134e+06
# Genes.Quantity                                                          NaN
# Genes.Normalised                                                        NaN
# Genes.MaxLFQ                                                            NaN
# ...

# %% [markdown]
# One spectral library

# %%
# !/home/ekvall/diann/diann-linux --f /sdd/proteomics/DATA/PXD014076/mzML/Symb_Proteome_DIA_RAW_S01.mzML \
--f /sdd/proteomics/DATA/PXD014076/mzML/Symb_Proteome_DIA_RAW_S02.mzML \
--lib /home/ekvall/Desktop/sample_comp_one_lib/library.tsv \
--out /home/ekvall/Desktop/sample_comp_one_lib/diann_S1_2.tsv
# Out:
# DIA-NN 1.7.12 (Data Independent Acquisition by Neural Networks)
# Compiled on Feb 13 2021 17:30:41
# Current date and time: Mon Mar  1 09:52:41 2021
# Logical CPU cores: 8
#
# 2 files will be processed
# [0:00] Loading spectral library /home/ekvall/Desktop/sample_comp_one_lib/library.tsv
# [0:00] Finding proteotypic peptides (assuming that the list of UniProt ids provided for each peptide is complete)
# [0:00] Spectral library loaded: 155 protein isoforms, 155 protein groups and 173 precursors in 173 elution groups.
# [0:00] Initialising library
# [0:00] Saving the library to /home/ekvall/Desktop/sample_comp_one_lib/library.tsv.speclib
#
# [0:00] File #1/2
# [0:00] Loading run /sdd/proteomics/DATA/PXD014076/mzML/Symb_Proteome_DIA_RAW_S01.mzML
# [0:26] 173 library precursors are potentially detectable
# [0:26] Processing...
# [0:29] RT window set to 2.40145
# [0:29] Peak width: 4.98824
# [0:29] Scan window radius set to 10
# [0:30] Optimised mass accuracy: 5.21232 ppm
# ...

# %%
diann_stats_out = pd.read_csv("/home/ekvall/Desktop/sample_comp_one_lib/diann_S1_2.tsv", sep="\t")

# %%
diann_stats_out.shape
# Out:
# (311, 42)

# %%
diann_stats_out.head(4).T
# Out:
#                                                                           0  \
# File.Name                 /sdd/proteomics/DATA/PXD014076/mzML/Symb_Prote...
# Run                                               Symb_Proteome_DIA_RAW_S01
# Protein.Group                                                  AIPGENE23810
# Protein.Ids                                                    AIPGENE23810
# Protein.Names                                                           NaN
# Genes                                                                   NaN
# PG.Quantity                                                     2.98267e+06
# PG.Normalised                                                   2.88189e+06
# Genes.Quantity                                                          NaN
# Genes.Normalised                                                        NaN
# Genes.MaxLFQ                                                            NaN
# ...
